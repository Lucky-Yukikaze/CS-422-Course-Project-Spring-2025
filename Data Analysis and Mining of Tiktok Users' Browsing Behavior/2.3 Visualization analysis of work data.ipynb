# %% [markdown]
# Data Visualization Analysis - Feature Analysis of Works

# %%
import pandas as pd
import numpy as np

from pyecharts.charts import *
from pyecharts import options as opts

# %% [markdown]
# Drawing function encapsulation

# %%
def line_chart(t, data):
    chart = (
        Line(init_opts = opts.InitOpts(theme='dark', width='600px', height='450px'))
        .add_xaxis([i[0] for i in data])
        .add_yaxis(
            '',
            [i[1] for i in data],
            is_symbol_show=False,
            areastyle_opts=opts.AreaStyleOpts(opacity=1, color="cyan")
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title=t),
            xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=True),
            yaxis_opts=opts.AxisOpts(
                type_="value",
                axistick_opts=opts.AxisTickOpts(is_show=True),
                splitline_opts=opts.SplitLineOpts(is_show=True),
            ),
        )
    )
    return chart

# %%
def pie_chart(t, data_pair):
    #Create a new pie chart
    chart = (
        Pie(init_opts=opts.InitOpts(theme='dark', width='600px', height='400px'))
        .add('', data_pair ,radius=["30%", "45%"], #Radius range, inner and outer diameters
            label_opts=opts.LabelOpts(formatter="{b}: {d}%") #Label setting, {d} represents display percentage
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(
                title=t
             ),
            legend_opts=opts.LegendOpts(pos_left="0%",pos_top="55",orient='vertical')
        )
    )
    return chart

# %% [markdown]
# 3.1 Data Fetch

# %%
df =  pd.read_csv('douyin_dataset.csv')
del df['Unnamed: 0']
item_df = pd.read_csv('features_of_the_work.csv')
item_df.head()
# Out:
#    item_id  Page_view  Like_count  Publish_city  Background_music
# 0        0         24           0          24.0             220.0
# 1        1       1309           5          63.0             574.0
# 2        3          2           0           7.0           26289.0
# 3        4        613           3         146.0             162.0
# 4        7          2           0          33.0             540.0

# %% [markdown]
# 3.2 Daily release status of works

# %%
#Count the number of works released on each day
data = df.groupby(['date']).agg({'item_id':pd.Series.nunique}).reset_index().values.tolist()
line_chart("Daily daily publication volume of works", data).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e2e761c2d1294a7f90a7b17b4541f189" style="width:600px; height:450px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e2e761c2d1294a7f90a7b17b4541f189 = echarts.init(
#                     document.getElementById('e2e761c2d1294a7f90a7b17b4541f189'), 'dark', {renderer: 'canvas'});
#                 var option_e2e761c2d1294a7f90a7b17b4541f189 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "2019-09-21",
#                     93
#                 ],
#                 [
#                     "2019-09-22",
#                     734
#                 ],
#                 [
#                     "2019-09-23",
#                     1267
#                 ],
#                 [
#                     "2019-09-24",
#                     1929
#                 ],
#                 [
#                     "2019-09-25",
#                     2605
#                 ],
#                 [
#                     "2019-09-26",
#                     2935
#                 ],
#                 [
#                     "2019-09-27",
#                     3511
#                 ],
#                 [
#                     "2019-09-28",
#                     3803
#                 ],
#                 [
#                     "2019-09-29",
#                     4294
#                 ],
#                 [
#                     "2019-09-30",
#                     5225
#                 ],
#                 [
#                     "2019-10-01",
#                     5088
#                 ],
#                 [
#                     "2019-10-02",
#                     5386
#                 ],
#                 [
#                     "2019-10-03",
#                     6014
#                 ],
#                 [
#                     "2019-10-04",
#                     6221
#                 ],
#                 [
#                     "2019-10-05",
#                     6403
#                 ],
#                 [
#                     "2019-10-06",
#                     6641
#                 ],
#                 [
#                     "2019-10-07",
#                     7085
#                 ],
#                 [
#                     "2019-10-08",
#                     7097
#                 ],
#                 [
#                     "2019-10-09",
#                     6704
#                 ],
#                 [
#                     "2019-10-10",
#                     6715
#                 ],
#                 [
#                     "2019-10-11",
#                     6728
#                 ],
#                 [
#                     "2019-10-12",
#                     7267
#                 ],
#                 [
#                     "2019-10-13",
#                     7574
#                 ],
#                 [
#                     "2019-10-14",
#                     7719
#                 ],
#                 [
#                     "2019-10-15",
#                     8178
#                 ],
#                 [
#                     "2019-10-16",
#                     7940
#                 ],
#                 [
#                     "2019-10-17",
#                     8347
#                 ],
#                 [
#                     "2019-10-18",
#                     8861
#                 ],
#                 [
#                     "2019-10-19",
#                     9824
#                 ],
#                 [
#                     "2019-10-20",
#                     10609
#                 ],
#                 [
#                     "2019-10-21",
#                     20511
#                 ],
#                 [
#                     "2019-10-22",
#                     29686
#                 ],
#                 [
#                     "2019-10-23",
#                     31921
#                 ],
#                 [
#                     "2019-10-24",
#                     31851
#                 ],
#                 [
#                     "2019-10-25",
#                     30549
#                 ],
#                 [
#                     "2019-10-26",
#                     31014
#                 ],
#                 [
#                     "2019-10-27",
#                     31903
#                 ],
#                 [
#                     "2019-10-28",
#                     28793
#                 ],
#                 [
#                     "2019-10-29",
#                     27844
#                 ],
#                 [
#                     "2019-10-30",
#                     12603
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "valueAnimation": false
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": "cyan"
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": true,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "animation": true,
#             "animationThreshold": 2000,
#             "animationDuration": 1000,
#             "animationEasing": "cubicOut",
#             "animationDelay": 0,
#             "animationDurationUpdate": 300,
#             "animationEasingUpdate": "cubicOut",
#             "animationDelayUpdate": 0,
#             "data": [
#                 "2019-

# %% [markdown]
# 3.3 Page views of works

# %%
bins = [0, 1, 2, 4, 2000]
item_df['Browse volume level'] = pd.cut(item_df['Page_view'], bins, labels=[f'({bins[x]},{bins[x+1]}]' for x in range(len(bins)-1)])
data = item_df.groupby('Browse volume level')['Page_view'].count().reset_index().values.tolist()
pie_chart('Distribution of views on works', data).render_notebook()
# Out:
# C:\Users\Lucky Yukikaze\AppData\Local\Temp\ipykernel_17812\3542306791.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data = item_df.groupby('Browse volume level')['Page_view'].count().reset_index().values.tolist()
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7fa63d1d796c4f3ab3927b31bb869eb8" style="width:600px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7fa63d1d796c4f3ab3927b31bb869eb8 = echarts.init(
#                     document.getElementById('7fa63d1d796c4f3ab3927b31bb869eb8'), 'dark', {renderer: 'canvas'});
#                 var option_7fa63d1d796c4f3ab3927b31bb869eb8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "(0,1]",
#                     "value": 284761
#                 },
#                 {
#                     "name": "(1,2]",
#                     "value": 58970
#                 },
#                 {
#                     "name": "(2,4]",
#                     "value": 45281
#                 },
#                 {
#                     "name": "(4,2000]",
#                     "value": 60460
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "(0,1]",
#                 "(1,2]",
#                 "(2,4]",
#                 "(4,2000]"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "55",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Distribution of views on works",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_7fa63d1d796c4f3ab3927b31bb869eb8.setOption(option_7fa63d1d796c4f3ab3927b31bb869eb8);
#         });
#     </script>

# %% [markdown]
# 3.4 Like rate of works

# %%
bins = [-1, 0, 1, 3, 5, 10, 50]
item_df['Like level'] = pd.cut(item_df['Like_count'], bins, labels=[f'[{bins[x]},{bins[x+1]})' for x in range(len(bins)-1)], right=False)
data = item_df.groupby('Like level')['Like_count'].sum().reset_index().values.tolist()
pie_chart('Distribution of likes', data).render_notebook()
# Out:
# C:\Users\Lucky Yukikaze\AppData\Local\Temp\ipykernel_17812\1888565992.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data = item_df.groupby('Like level')['Like_count'].sum().reset_index().values.tolist()
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b8a67fa46e024319bf498c32a14ad7c7" style="width:600px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b8a67fa46e024319bf498c32a14ad7c7 = echarts.init(
#                     document.getElementById('b8a67fa46e024319bf498c32a14ad7c7'), 'dark', {renderer: 'canvas'});
#                 var option_b8a67fa46e024319bf498c32a14ad7c7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "[-1,0)",
#                     "value": 0
#                 },
#                 {
#                     "name": "[0,1)",
#                     "value": 0
#                 },
#                 {
#                     "name": "[1,3)",
#                     "value": 13521
#                 },
#                 {
#                     "name": "[3,5)",
#                     "value": 1458
#                 },
#                 {
#                     "name": "[5,10)",
#                     "value": 1130
#                 },
#                 {
#                     "name": "[10,50)",
#                     "value": 664
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "[-1,0)",
#                 "[0,1)",
#                 "[1,3)",
#                 "[3,5)",
#                 "[5,10)",
#                 "[10,50)"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "55",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Distribution of likes",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_b8a67fa46e024319bf498c32a14ad7c7.setOption(option_b8a67fa46e024319bf498c32a14ad7c7);
#         });
#     </script>
